# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(20.0,10.0)

data = pd.read_csv(r'C:\Users\anish\Downloads\headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = data["Head Size(cm^3)"]
Y = data["Brain Weight(grams)"]

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)
n= len(X)
numer = 0
denom = 0
for i in range (n):
    numer+=(X[i]-mean_x)*(Y[i]-mean_y)
    denom+=(X[i]-mean_x)**2
b1=numer/denom
b0=mean_y-(b1*mean_x)
print(b1,b0)
# Out:
# 0.26342933948939945 325.57342104944223

# %%
max_x=np.max(X)+100
min_x=np.min(X)-100
x=np.linspace(min_x,max_x,1000)
y=b0+x*b1
plt.plot(x,y,color="#dc143c",label="Regression Line")
plt.scatter(X,Y,c="#ffa500",label="Scatter Plot")

plt.xlabel("Head size in cm^3")
plt.ylabel("Brain Weight in grams")
plt.legend()
plt.show()

# %%
ss_t=0
ss_r=0
for i in range(n):
    y_pred = b0+ b1*X[i]
    ss_t +=(Y[i]-mean_y)**2
    ss_r +=(Y[i]-y_pred)**2
r2=1-(ss_r/ss_t)
print(r2)
# Out:
# 0.6393117199570003

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = X.values.reshape((n,1))
reg = LinearRegression()
reg=reg.fit(X,Y)
Y_pred=reg.predict(X)
r2_score = reg.score(X,Y)
print(r2_score)
# Out:
# 0.639311719957
